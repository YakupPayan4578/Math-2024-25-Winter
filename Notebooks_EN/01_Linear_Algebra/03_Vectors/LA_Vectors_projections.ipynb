# %% [markdown]
# # Vectors - Projections and Divisions
#
#
# ## Projecting a Vector onto Another Vector
#
# Projecting vector $\mathbf{a}$ onto axis $\mathbf{b}$ involves finding the component of vector $\mathbf{a}$ along the direction of $\mathbf{b}$.
#
# Projection of $\mathbf{a}$ onto $\mathbf{b}$:
#
# $$
# \text{Proj}_{\mathbf{b}} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{b}}{|\mathbf{b}|^2} \mathbf{b}
# $$
#
#
# ## Projecting a Vector onto Axes
#
# Projecting vector $\mathbf{a}$ onto an axis involves finding the component of vector $\mathbf{a}$ along that axis.
#
# Projection of $\mathbf{a}$ onto the $OX$ axis:
#
# $$
# \text{Proj}_{OX} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{i}}{|\mathbf{i}|^2} \mathbf{i} = \frac{\mathbf{a} \cdot \mathbf{i}}{1} \mathbf{i} = (\mathbf{a} \cdot \mathbf{i}) \mathbf{i}
# $$
#
# Projection of $\mathbf{a}$ onto the $OY$ axis:
#
# $$
# \text{Proj}_{OY} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{j}}{|\mathbf{j}|^2} \mathbf{j} = \frac{\mathbf{a} \cdot \mathbf{j}}{1} \mathbf{j} = (\mathbf{a} \cdot \mathbf{j}) \mathbf{j}
# $$
#
# Recall that $\mathbf{i} = (1, 0)$ and $\mathbf{j} = (0, 1)$ are unit vectors along the $OX$ and $OY$ axes.
#
#
# ## Dividing a Line Segment in a Given Ratio
#
# A line segment is defined by two points in space.
#
# Line segments and vectors are closely related because a line segment connecting two points can be treated as a vector directed from one point to another.
#
# If point \( P \) divides the line segment connecting points $A(x_1, y_1)$ and $B(x_2, y_2)$ in the ratio $m:n$, then the coordinates of point $P$ can be found using the formula:
#
# $$
# P = \left(\frac{n \times x_2 + m \times x_1}{m+n}, \frac{n \times y_2 + m \times y_1}{m+n}\right)
# $$
#
# **Example:**
#
# Given a line segment connecting points $A(1, 2)$ and $B(3, 8)$, find point $P$ that divides the segment in the ratio 2:3.
#
# Coordinates of point $P$:
# $$
# P = \left(\frac{2 \times 3 + 3 \times 1}{2+3}, \frac{2 \times 8 + 3 \times 2}{2+3}\right) = \left(\frac{9}{5}, \frac{22}{5}\right)
# $$

# %%
import matplotlib.pyplot as plt
import math

# Coordinates of points A and B
A = (1, 2)
B = (3, 8)

# Ratio m:n
m, n = 2, 3

# Calculate coordinates of point P that divides the segment in the ratio 2:3
P_x = (n * A[0] + m * B[0]) / (m + n)
P_y = (n * A[1] + m * B[1]) / (m + n)
P = (P_x, P_y)

# Plotting the graph
plt.figure(figsize=(6, 6))

# Plotting line segment AB
plt.plot([A[0], B[0]], [A[1], B[1]], 'k--', label='Line Segment AB')

# Marking points A, B, and P
plt.scatter(*A, color='blue', label='A(1, 2)')
plt.scatter(*B, color='red', label='B(3, 8)')
plt.scatter(*P, color='green', label=f'P({P[0]:.2f}, {P[1]:.2f})')

# Point labels
plt.text(A[0]-0.2, A[1], 'A(1, 2)', fontsize=12, color='blue')
plt.text(B[0]+0.1, B[1], 'B(3, 8)', fontsize=12, color='red')
plt.text(P[0]+0.1, P[1], f'P({P[0]:.2f}, {P[1]:.2f})', fontsize=12, color='green')

# Adding grid and axis labels
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dividing a Line Segment in the Ratio 2:3')
plt.legend()

# Displaying the graph
plt.show()

# %% [raw]
# ---

# %% [markdown]
# ## Student Exercises
#
# - Divide the line segment connecting points $A(-1, 2)$ and $B(3, -2)$ in the ratio $1:3$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (3, 4)$ onto the $OX$ and $OY$ axes. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (2,3)$ onto vector $\mathbf{b} = (1, 1)$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{b} = (1, 1)$ onto vector $\mathbf{a} = (2, 3)$. Illustrate the result on a graph.

# %%
# Import necessary library
import matplotlib.pyplot as plt
print("Exercise 1")
# Define the points A(-1, 2) and B(3, -2)
A = (-1, 2)
B = (3, -2)

# Ratio m:n = 1:3, where m=1 and n=3
m = 1
n = 3

# Calculate the coordinates of the dividing point
x = (m * B[0] + n * A[0]) / (m + n)
y = (m * B[1] + n * A[1]) / (m + n)

# Plot the points and the line segment
plt.figure(figsize=(6, 6))

# Plot points A, B, and the dividing point
plt.plot([A[0], B[0]], [A[1], B[1]], color='black', label='Line Segment AB')
plt.scatter([A[0], B[0], x], [A[1], B[1], y], color='red')  # A, B, and dividing point
plt.text(A[0], A[1], 'A(-1, 2)', fontsize=12, ha='right')
plt.text(B[0], B[1], 'B(3, -2)', fontsize=12, ha='right')
plt.text(x, y, f'P({x:.2f}, {y:.2f})', fontsize=12, ha='right')

# Customize the plot
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Line Segment Divided in the Ratio 1:3')

# Show the plot
plt.legend()
plt.show()

# Print the dividing point coordinates
print(f"Dividing point P: ({x:.2f}, {y:.2f})")
# Out:
# Exercise 1
# Dividing point P: (0.00, 1.00)

# %%
# Import necessary library
import matplotlib.pyplot as plt
print("Exercise 2")
# Define the vector a(3, 4)
a = (3, 4)

# OX axis projection (only the x-component)
proj_ox = (a[0], 0)

# OY axis projection (only the y-component)
proj_oy = (0, a[1])

# Plot the vector a and its projections onto OX and OY axes
plt.figure(figsize=(6, 6))

# Plot vector a
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='a = (3, 4)')
# Plot projection onto OX
plt.quiver(0, 0, proj_ox[0], proj_ox[1], angles='xy', scale_units='xy', scale=1, color='green', label='Projection on OX')
# Plot projection onto OY
plt.quiver(0, 0, proj_oy[0], proj_oy[1], angles='xy', scale_units='xy', scale=1, color='red', label='Projection on OY')

# Customize the plot
plt.xlim(-1, 4)
plt.ylim(-1, 5)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Vector a and its projections onto OX and OY axes')

# Show the plot
plt.legend()
plt.show()
# Out:
# Exercise 2

# %%
# Import necessary library
import matplotlib.pyplot as plt
import numpy as np
print("Exercise 3")
# Define the vectors a(2, 3) and b(1, 1)
a = np.array([2, 3])
b = np.array([1, 1])

# Calculate the projection of a onto b using the formula
proj_b_a = (np.dot(a, b) / np.dot(b, b)) * b

# Plot the vectors and the projection
plt.figure(figsize=(6, 6))

# Plot vector a and b
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='a = (2, 3)')
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='green', label='b = (1, 1)')

# Plot the projection of a onto b
plt.quiver(0, 0, proj_b_a[0], proj_b_a[1], angles='xy', scale_units='xy', scale=1, color='red', label='Projection of a onto b')

# Customize the plot
plt.xlim(-1, 3)
plt.ylim(-1, 4)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Projection of Vector a onto Vector b')

# Show the plot
plt.legend()
plt.show()

# Print the projection coordinates
print(f"Projection of a onto b: ({proj_b_a[0]:.2f}, {proj_b_a[1]:.2f})")
# Out:
# Exercise 3
# Projection of a onto b: (2.50, 2.50)

# %%
# Import necessary library
import matplotlib.pyplot as plt
import numpy as np
print("Exercise 4")
# Define the vectors a(2, 3) and b(1, 1)
a = np.array([2, 3])
b = np.array([1, 1])

# Calculate the projection of b onto a using the formula
proj_a_b = (np.dot(b, a) / np.dot(a, a)) * a

# Plot the vectors and the projection
plt.figure(figsize=(6, 6))

# Plot vector a and b
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label='a = (2, 3)')
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='green', label='b = (1, 1)')

# Plot the projection of b onto a
plt.quiver(0, 0, proj_a_b[0], proj_a_b[1], angles='xy', scale_units='xy', scale=1, color='red', label='Projection of b onto a')

# Customize the plot
plt.xlim(-1, 3)
plt.ylim(-1, 4)
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.grid(True)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Projection of Vector b onto Vector a')

# Show the plot
plt.legend()
plt.show()

# Print the projection coordinates
print(f"Projection of b onto a: ({proj_a_b[0]:.2f}, {proj_a_b[1]:.2f})")
# Out:
# Exercise 4
# Projection of b onto a: (0.77, 1.15)
